# %%
import re  # Import the regular expression module
import requests  # Import the requests library
from bs4 import BeautifulSoup as b  # Import BeautifulSoup for HTML parsing
import pandas as pd  # Import pandas for data manipulation

# Define the URL and user agent
url = 'https://www.imdb.com/chart/top'
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'
}

# Fetch the HTML content from the URL
response = requests.get(url, headers=headers).text

# Parse the HTML using BeautifulSoup
soup = b(response, 'html.parser')

# Define a regex pattern to extract movie information
pattern = r'(\d+).\s+(.+?)(\d{4})(\d{0,2}h\s+\w+)(\d.\d)Rate'

# Find movie information using the regex pattern
movie_info = re.findall(pattern, paragraph)

# Create a list to store movie details
movielist = []
for i in movie_info:
    movielist.append({
        'ranking': i[0],
        'movie': i[1],
        "year_of_release": i[2],
        'duration': re.sub(r'[UA]', '', i[3]),  # Remove 'UA' from duration
        'rating': i[4]
    })

# Create a DataFrame from the movie list
df = pd.DataFrame(movielist)

# Display the DataFrame with movie details
display(df)

# Note: Saving the DataFrame to a CSV file is attempted but may require proper file path and permissions
# df.to_csv('C:\ you can use file path here to save')
# Out:
#     ranking                                              movie  \
# 0         1                           The Shawshank Redemption
# 1         2                                      The Godfather
# 2         3                                    The Dark Knight
# 3         4                             The Godfather: Part II
# 4         5                                       12 Angry Men
# ..      ...                                                ...
# 229     245  Persona19661h 25mNot Rated8.1Rate246. The Iron...
# 230     247                                           The Help
# 231     248                                      Life of Brian
# 232     249                                            Aladdin
# 233     250                                 Dances with Wolves
#
#     year_of_release duration rating
# 0              1994   2h 22m    9.3
# 1              1972   2h 55m    9.2
# 2              2008   2h 32m    9.0
# 3              1974   3h 22m    9.0
# ...
